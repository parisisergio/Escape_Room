# %%
# define rooms and items

#>>>>>>>>>>>>>>>>>>>>>>>>>> Furniture list>>>>>>>>>>>>>>>>>.
##Control Room Furniture list
commander_seat = {
    "name": "commander seat",
    "type": "furniture",
}

instrument_panel = {
    "name": "instrument panel",
    "type": "furniture",
}

##Engine Room Furniture list

cupola_window = {
    "name": "cupola window",
    "type": "furniture",
}
zero_gravity_bed= {
    "name": "zero gravity bed",
    "type": "furniture",
}
space_training_machine = {
    "name": "space training machine",
    "type": "furniture",
}
closet = {
    "name": "closet",
    "type": "furniture",
}
# Laboratory room Furniture list

cabinet = {
    "name": "cabinet",
    "type": "furniture",
}
experiment_table = {
    "name": "experiment table",
    "type": "furniture",
}
greenhouse = {
    "name": "greenhouse",
    "type": "furniture",
}

cabinet = {
    "name": "cabinet",
    "type": "furniture",
}
experiment_table = {
    "name": "experiment table",
    "type": "furniture",
}
greenhouse = {
    "name": "greenhouse",
    "type": "furniture",
}

# Doors List
alpha_door = { 
    "name": "alpha door",
     "type": "door",
}

beta_door = {
    "name": "beta door",
    "type": "door",
}

gamma_door = {
    "name": "gamma door",
    "type": "door",
}

space_door = {
    "name": "space door",
    "type": "door",
}

gamma_door = {
    "name": "gamma door",
    "type": "door",
}


## Docking room Furniture list

dirty_box = {
    "name": "dirty box",
    "type": "furniture",
}

weird_bag = {
    "name": "weird bag",
    "type": "furniture",
}

# Keys list
card_alpha = {
    "name": "access card alpha",
    "type": "key",
    "target": alpha_door,
}
card_beta = {
    "name": "access card beta",
    "type": "key",
    "target": beta_door,
}
card_gamma = {
    "name": "access card gamma",
    "type": "key",
    "target": gamma_door,
}
card_space = {
    "name": "space card",
    "type": "key",
    "target": space_door,
}


# Rooms list

control_room = {
    "name": "control room",
    "type": "room",
}
engine_room = {
    "name": "engine room",
    "type": "room",
}
laboratory = {
    "name": "laboratory",
    "type": "room",
}
docking_room = {
    "name": "docking room",
    "type": "room",
}
space = {
    "name": "space",
    "type": "room",
}
# Survival Items
galactic_gps = {
    "name": "galactic gps",
    "type": "survival_item",
    "target": "",
}
dog = {
    "name": "my dog David",
    "type": "survival_item",
    "target": "",
}
picture = {
    "name": "my best friend Gonzalo",
    "type": "survival_item",
    "target": "",
}
fuel = {
    "name": "fuel",
    "type": "survival_item",
    "target": "",
}
huggable_bear = {
    "name": "huggable bear",
    "type": "survival_item",
    "target": "",
}

lady_gaga_physical_album = {
    "name": "Lady Gaga's physical album",
    "type": "survival_item",
    "target": "",
}


# all_rooms = [control_room, engine_room,laboratory,]

# all_doors = [door_a, door_b, door_c, door_d]

# define which items/rooms are related

object_relations = {
#room relations
    "control room": [ commander_seat, instrument_panel, alpha_door],
    "engine room": [cupola_window,  zero_gravity_bed, space_training_machine, closet,beta_door, gamma_door,alpha_door],
    "laboratory": [cabinet, experiment_table,greenhouse,beta_door],
    "docking room": [gamma_door, space_door, dirty_box, weird_bag],

#doors relations
    "alpha door": [control_room, engine_room],
    "beta door": [engine_room, laboratory],
    "space door": [docking_room,space],
    "gamma door": [engine_room, docking_room],
#Items relations
    "commander seat": [card_alpha],
    "closet": [picture],
    "cabinet": [fuel],
    "dirty box": [lady_gaga_physical_album],
    "instrument panel": [galactic_gps],
    "zero gravity bed": [dog],
    "space training machine": [card_beta],
    "greenhouse": [card_space],
    "experiment table": [card_gamma],
    "weird bag": [huggable_bear],
}

# define game state. Do not directly change this dict. 
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This 
# way you can replay the game multiple times.

INIT_GAME_STATE = {
    "current_room": control_room,
    "keys_collected": [],
    "items_collected": [],
    "target_room": space
}

# %%
def linebreak():
    """
    Print a line break
    """
    print("\n\n")

def start_game():
    """
    Start the game
    """
    print("You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!")
    play_room(game_state["current_room"]) ##### first step of the room

    ##### Starts in game_room (initialized in state)
    ##### value gets update when go_to_next_room functions gets called

def play_room(room):
    """
    Play a room. First check if the room being played is the target room.
    If it is, the game will end with success. Otherwise, let player either 
    explore (list all items in this room) or examine an item found here.
    """
    game_state["current_room"] = room ##### stores in a variable the room for better readibility 
    if(game_state["current_room"] == game_state["target_room"]): 
        print("Congrats! You escaped the room!") ##### validates if you win or not
    else:
        print("You are now in " + room["name"]) ##### uses the name value of the game_room dict, this would be something like  game_state["current_room"]["name"]
        intended_action = input("What would you like to do? Type 'explore' or 'examine'?").strip() 
        if intended_action == "explore":
            explore_room(room) ##### shows the items in the room depending on the current room
            play_room(room) ##### restart the process with print "You are now in room" 
        elif intended_action == "examine": 
            examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
        else:
            print("Not sure what you mean. Type 'explore' or 'examine'.")
            play_room(room)
        linebreak()

def explore_room(room):
    """
    Explore a room. List all items belonging to this room.
    """
    items = [i["name"] for i in object_relations[room["name"]]] ##### defines a list of the items in current room (need to update object relations for each room)
    print("You explore the room. This is " + room["name"] + ". You find " + ", ".join(items))

def get_next_room_of_door(door, current_room):
    """
    From object_relations, find the two rooms connected to the given door.
    Return the room that is not the current_room.
    """
    connected_rooms = object_relations[door["name"]] ##### find relations of items to get the specific room
    for room in connected_rooms: 
        if(not current_room == room): ##### loops through the rooms to check if the current room is not the one that object relations points to and returned it 
            return room

def examine_item(item_name): ##### gets an input to examine
    """
    Examine an item which can be a door or furniture.
    First make sure the intended item belongs to the current room.
    Then check if the item is a door. Tell player if key hasn't been 
    collected yet. Otherwise ask player if they want to go to the next
    room. If the item is not a door, then check if it contains keys.
    Collect the key if found and update the game state. At the end,
    play either the current or the next room depending on the game state
    to keep playing.
    """
    current_room = game_state["current_room"] ##### defined as variable for future use in get_door_next_room
    next_room = ""
    output = None
    
    for item in object_relations[current_room["name"]]: ##### loop items list of current room values - for game_room would be couch, piano and door a
        if(item["name"] == item_name): ##### validates if input matches the object relations values 
            output = "You examine " + item_name + ". "
            if(item["type"] == "door"): 
                have_key = False
                for key in game_state["keys_collected"]: ##### checks for keys of the dict values
                    if(key["target"] == item): ##### validates if that specific key opens that door (item)
                        have_key = True ##### turns the state to true if the key opens that door (item)
                if(have_key):
                    output += "You unlock it with a key you have." ##### appends the string value 
                    next_room = get_next_room_of_door(item, current_room) ##### item is a door - apply get_next_room_of_door function
                else:
                    output += "It is locked but you don't have the key." ##### have_key remains false and blocks the process
            else: ##### this happens when the item is not a door
                if(item["name"] in object_relations and len(object_relations[item["name"]])>0):  ### when the item is at least one time present in object relations dict
                    item_found = object_relations[item["name"]].pop() ##### removes the key from the objet relations of the specific item, if all the keys are collected all the related items should be without value
                    game_state["keys_collected"].append(item_found) ##### adds the key to the collected state
                    output += "You find " + item_found["name"] + "." ##### shows the key name
                    print(f"The collected items & cards are: {[i['name'] for i in game_state['keys_collected']]}")
                else:
                    output += "There isn't anything interesting about it." ##### item is selected and key is not present in there
            print(output)
            break 

    if(output is None):
        print("The item you requested is not found in the current room.") ##### write an item that is not the one in the explore function
    
    if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'): ##### if next_room exists (defined after key is used when get_next_room fucntion is applied)
        play_room(next_room) ##### uses the target value of the item when the key is used 
    else:
        play_room(current_room) ##### leaves you in the previous room if you say no

# %%
game_state = INIT_GAME_STATE.copy()

start_game()

# %%
game_state = INIT_GAME_STATE.copy()

start_game()
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is control room. You find commander seat, instrument panel, alpha door
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?commander seat
# You examine commander seat. There isn't anything interesting about it.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?instrument panel
# You examine instrument panel. There isn't anything interesting about it.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?alpha door
# cual la llave?: {'name': 'access card alpha', 'type': 'key', 'target': {'name': 'alpha door', 'type': 'door'}}
# que llaves se recolectaron?: [{'name': 'access card alpha', 'type': 'key', 'target': {'name': 'alpha door', 'type': 'door'}}, {'name': 'galactic gps', 'type': 'survival_item'}]
# tiene la llave?: True
# cual la llave?: {'name': 'galactic gps', 'type': 'survival_item'}
# que llaves se recolectaron?: [{'name': 'access card alpha', 'type': 'key', 'target': {'name': 'alpha door', 'type': 'door'}}, {'name': 'galactic gps', 'type': 'survival_item'}]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-2c0d15a1ff83> in <module>()
#       1 game_state = INIT_GAME_STATE.copy()
#       2
# ----> 3 start_game()
#
# <ipython-input-51-61583bae792a> in start_game()
#      10     """
#      11     print("You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!")
# ---> 12     play_room(game_state["current_room"]) ##### first step of the room
#      13
#      14     ##### Starts in game_room (initialized in state)
#
# <ipython-input-51-61583bae792a> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-51-61583bae792a> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-51-61583bae792a> in examine_item(item_name)
#     101         play_room(next_room) ##### uses the target value of the item when the key is used
#     102     else:
# --> 103         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-51-61583bae792a> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-51-61583bae792a> in examine_item(item_name)
#     101         play_room(next_room) ##### uses the target value of the item when the key is used
#     102     else:
# --> 103         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-51-61583bae792a> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-51-61583bae792a> in examine_item(item_name)
#      77                     print(f"cual la llave?: {key}")
#      78                     print(f"que llaves se recolectaron?: {game_state['keys_collected']}")
# ---> 79                     if(key["target"] == item): ##### validates if that specific key opens that door (item)
#      80                         have_key = True ##### turns the state to true if the key opens that door (item)
#      81                         print(f"tiene la llave?: {have_key}")
#
# KeyError: 'target'

# %%
game_state = INIT_GAME_STATE.copy()

start_game() #added an empty target to galactic gps because they are being treated as keys
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is control room. You find commander seat, instrument panel, alpha door
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?commander seat
# You examine commander seat. You find access card alpha.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?instrument panel
# You examine instrument panel. You find galactic gps.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?alpha door
# You examine alpha door. You unlock it with a key you have.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-2c0d15a1ff83> in <module>()
#       1 game_state = INIT_GAME_STATE.copy()
#       2
# ----> 3 start_game()
#
# <ipython-input-63-96ac364f964e> in start_game()
#      10     """
#      11     print("You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!")
# ---> 12     play_room(game_state["current_room"]) ##### first step of the room
#      13
#      14     ##### Starts in game_room (initialized in state)
#
# <ipython-input-63-96ac364f964e> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-63-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-63-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-63-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-63-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-63-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-63-96ac364f964e> in examine_item(item_name)
#      95         print("The item you requested is not found in the current room.") ##### write an item that is not the one in the explore function
#      96
# ---> 97     if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'): ##### if next_room exists (defined after key is used when get_next_room fucntion is applied)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
game_state = INIT_GAME_STATE.copy()

start_game() # card for laboratory is not showing up on space machine
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is control room. You find commander seat, instrument panel, alpha door
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?commander seat
# You examine commander seat. You find access card alpha.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?instrument panel
# You examine instrument panel. You find galactic gps.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?alpha door
# You examine alpha door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is engine room. You find cupola window, zero gravity bed, space training machine, closet, beta door, gamma door, alpha door
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?cupola window
# You examine cupola window. There isn't anything interesting about it.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?zero gravity bed
# You examine zero gravity bed. There isn't anything interesting about it.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?space training machine
# You examine space training machine. There isn't anything interesting about it.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?closet
# You examine closet. You find my best friend Gonzalo.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?beta door
# You examine beta door. It is locked but you don't have the key.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?gamma door
# You examine gamma door. It is locked but you don't have the key.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?alpha door
# You examine alpha door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is control room. You find commander seat, instrument panel, alpha door
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?alpha door
# You examine alpha door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is engine room. You find cupola window, zero gravity bed, space training machine, closet, beta door, gamma door, alpha door
# You are now in engine room
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-e4200650bc74> in <module>()
#       1 game_state = INIT_GAME_STATE.copy()
#       2
# ----> 3 start_game()
#
# <ipython-input-66-96ac364f964e> in start_game()
#      10     """
#      11     print("You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!")
# ---> 12     play_room(game_state["current_room"]) ##### first step of the room
#      13
#      14     ##### Starts in game_room (initialized in state)
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-66-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-66-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-66-96ac364f964e> in examine_item(item_name)
#      96
#      97     if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'): ##### if next_room exists (defined after key is used when get_next_room fucntion is applied)
# ---> 98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
#     100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-66-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-66-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-66-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-66-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-66-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-66-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-66-96ac364f964e> in examine_item(item_name)
#      96
#      97     if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'): ##### if next_room exists (defined after key is used when get_next_room fucntion is applied)
# ---> 98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
#     100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-66-96ac364f964e> in examine_item(item_name)
#      96
#      97     if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'): ##### if next_room exists (defined after key is used when get_next_room fucntion is applied)
# ---> 98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
#     100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-66-96ac364f964e> in play_room(room)
#      26     else:
#      27         print("You are now in " + room["name"]) ##### uses the name value of the game_room dict, this would be something like  game_state["current_room"]["name"]
# ---> 28         intended_action = input("What would you like to do? Type 'explore' or 'examine'?").strip()
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
game_state = INIT_GAME_STATE.copy()

start_game() # removed _ from object relations because objects weren't mapped
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is control room. You find commander seat, instrument panel, alpha door
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?commander seat
# You examine commander seat. You find access card alpha.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?instrument panel
# You examine instrument panel. You find galactic gps.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?alpha door
# You examine alpha door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is engine room. You find cupola window, zero gravity bed, space training machine, closet, beta door, gamma door, alpha door
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?cupola window
# You examine cupola window. There isn't anything interesting about it.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?zero gravity bed
# You examine zero gravity bed. You find my dog David.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?space training machine
# You examine space training machine. You find access card beta.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?closet
# You examine closet. You find my best friend Gonzalo.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?beta door
# You examine beta door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in Laboratory
# What would you like to do? Type 'explore' or 'examine'?explore
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-6343b843d0ff> in <module>()
#       1 game_state = INIT_GAME_STATE.copy()
#       2
# ----> 3 start_game() # removed _ from object relations because objects weren't mapped
#
# <ipython-input-68-96ac364f964e> in start_game()
#      10     """
#      11     print("You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!")
# ---> 12     play_room(game_state["current_room"]) ##### first step of the room
#      13
#      14     ##### Starts in game_room (initialized in state)
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      96
#      97     if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'): ##### if next_room exists (defined after key is used when get_next_room fucntion is applied)
# ---> 98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
#     100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      96
#      97     if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'): ##### if next_room exists (defined after key is used when get_next_room fucntion is applied)
# ---> 98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
#     100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      28         intended_action = input("What would you like to do? Type 'explore' or 'examine'?").strip()
#      29         if intended_action == "explore":
# ---> 30             explore_room(room) ##### shows the items in the room depending on the current room
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#
# <ipython-input-68-96ac364f964e> in explore_room(room)
#      41     Explore a room. List all items belonging to this room.
#      42     """
# ---> 43     items = [i["name"] for i in object_relations[room["name"]]] ##### defines a list of the items in current room (need to update object relations for each room)
#      44     print("You explore the room. This is " + room["name"] + ". You find " + ", ".join(items))
#      45
#
# KeyError: 'Laboratory'

# %%
game_state = INIT_GAME_STATE.copy()

start_game() # change Laboratory to laboratory
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is control room. You find commander seat, instrument panel, alpha door
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?commander seat
# You examine commander seat. You find access card alpha.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?instrument panel
# You examine instrument panel. You find galactic gps.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?alpha door
# You examine alpha door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is engine room. You find cupola window, zero gravity bed, space training machine, closet, beta door, gamma door, alpha door
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?cupola window
# You examine cupola window. There isn't anything interesting about it.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?zero gravity bed
# You examine zero gravity bed. You find my dog David.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?space training machine
# You examine space training machine. You find access card beta.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?closet
# You examine closet. You find my best friend Gonzalo.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?beta door
# You examine beta door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is laboratory. You find cabinet, experiment table, greenhouse, beta door
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?cabinet
# You examine cabinet. You find fuel.
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?experiment table
# You examine experiment table. You find access card gamma.
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?greenhouse
# You examine greenhouse. You find space card.
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?beta door
# You examine beta door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is engine room. You find cupola window, zero gravity bed, space training machine, closet, beta door, gamma door, alpha door
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?gamma door
# You examine gamma door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in docking room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is docking room. You find gamma door, space door, dirt box, weird bag
# You are now in docking room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?dirt box
# You examine dirt box. There isn't anything interesting about it.
# You are now in docking room
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-8bc5d9813e14> in <module>()
#       1 game_state = INIT_GAME_STATE.copy()
#       2
# ----> 3 start_game() # change Laboratory to laboratory
#
# <ipython-input-68-96ac364f964e> in start_game()
#      10     """
#      11     print("You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!")
# ---> 12     play_room(game_state["current_room"]) ##### first step of the room
#      13
#      14     ##### Starts in game_room (initialized in state)
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      96
#      97     if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'): ##### if next_room exists (defined after key is used when get_next_room fucntion is applied)
# ---> 98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
#     100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      96
#      97     if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'): ##### if next_room exists (defined after key is used when get_next_room fucntion is applied)
# ---> 98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
#     100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      96
#      97     if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'): ##### if next_room exists (defined after key is used when get_next_room fucntion is applied)
# ---> 98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
#     100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      96
#      97     if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'): ##### if next_room exists (defined after key is used when get_next_room fucntion is applied)
# ---> 98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
#     100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
# ---> 31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
#      33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      31             play_room(room) ##### restart the process with print "You are now in room"
#      32         elif intended_action == "examine":
# ---> 33             examine_item(input("What would you like to examine?").strip()) ##### type a value of the ones specified in explore function
#      34         else:
#      35             print("Not sure what you mean. Type 'explore' or 'examine'.")
#
# <ipython-input-68-96ac364f964e> in examine_item(item_name)
#      98         play_room(next_room) ##### uses the target value of the item when the key is used
#      99     else:
# --> 100         play_room(current_room) ##### leaves you in the previous room if you say no
#
# <ipython-input-68-96ac364f964e> in play_room(room)
#      26     else:
#      27         print("You are now in " + room["name"]) ##### uses the name value of the game_room dict, this would be something like  game_state["current_room"]["name"]
# ---> 28         intended_action = input("What would you like to do? Type 'explore' or 'examine'?").strip()
#      29         if intended_action == "explore":
#      30             explore_room(room) ##### shows the items in the room depending on the current room
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
game_state = INIT_GAME_STATE.copy()

start_game() # change dirt box to dirty box
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is control room. You find commander seat, instrument panel, alpha door
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?commander seat
# You examine commander seat. You find access card alpha.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?instrument panel
# You examine instrument panel. You find galactic gps.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?alpha door
# You examine alpha door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is engine room. You find cupola window, zero gravity bed, space training machine, closet, beta door, gamma door, alpha door
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?cupola window
# You examine cupola window. There isn't anything interesting about it.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?zero gravity bed
# You examine zero gravity bed. You find my dog David.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?space training machine
# You examine space training machine. You find access card beta.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?closet
# You examine closet. You find my best friend Gonzalo.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?beta door
# You examine beta door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is laboratory. You find cabinet, experiment table, greenhouse, beta door
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?cabinet
# You examine cabinet. You find fuel.
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?experiment table
# You examine experiment table. You find access card gamma.
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?greenhouse
# You examine greenhouse. You find space card.
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?beta door
# You examine beta door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'explore
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?beta door
# You examine beta door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?gamma door
# You examine gamma door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in docking room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is docking room. You find gamma door, space door, dirty box, weird bag
# You are now in docking room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?dirty box
# You examine dirty box. You find Lady Gaga's physical album.
# You are now in docking room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?weird bag
# You examine weird bag. You find huggable bear.
# You are now in docking room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?space door
# You examine space door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# Congrats! You escaped the room!

# %%
game_state = INIT_GAME_STATE.copy()

start_game() # added a better print with list_status
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is control room. You find commander seat, instrument panel, alpha door
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examiner
# Not sure what you mean. Type 'explore' or 'examine'.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?commander seat
# The collected items & cards are: ['access card alpha']
# You examine commander seat. You find access card alpha.
# You are now in control room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?alpha door
# You examine alpha door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is engine room. You find cupola window, zero gravity bed, space training machine, closet, beta door, gamma door, alpha door
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?space training machine
# The collected items & cards are: ['access card alpha', 'access card beta']
# You examine space training machine. You find access card beta.
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?beta door
# You examine beta door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is laboratory. You find cabinet, experiment table, greenhouse, beta door
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?greenhouse
# The collected items & cards are: ['access card alpha', 'access card beta', 'space card']
# You examine greenhouse. You find space card.
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?experiment table
# The collected items & cards are: ['access card alpha', 'access card beta', 'space card', 'access card gamma']
# You examine experiment table. You find access card gamma.
# You are now in laboratory
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?beta door
# You examine beta door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in engine room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?gamma door
# You examine gamma door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# You are now in docking room
# What would you like to do? Type 'explore' or 'examine'?explore
# You explore the room. This is docking room. You find gamma door, space door, dirty box, weird bag
# You are now in docking room
# What would you like to do? Type 'explore' or 'examine'?examine
# What would you like to examine?space door
# You examine space door. You unlock it with a key you have.
# Do you want to go to the next room? Enter 'yes' or 'no'yes
# Congrats! You escaped the room!
